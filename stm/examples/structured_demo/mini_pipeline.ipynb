# %% [markdown]
# # Mini Pipeline: Structured Manifold Demo
# This notebook mirrors the CLI quick start for the bundled `news_sample.jsonl`. Either run the cells directly (if the repo is on the same machine) or copy/paste the commands into your shell.

# %%
# %%bash
# cd /sep/structural-manifold-compression
# source .venv/bin/activate
# python scripts/experiments/benchmark_eval.py \
#   --dataset briefs=examples/structured_demo/news_sample.jsonl \
#   --json-text-key text \
#   --window-bytes 512 --stride-bytes 384 --precision 3 \
#   --use-native \
#   --output-dir output/benchmark_runs/news_demo

# %% [markdown]
# Once the command finishes, open `output/benchmark_runs/news_demo/briefs.json` to inspect compression ratio, token accuracy, verification stats, and reconstructed snippets (under `per_document`).
